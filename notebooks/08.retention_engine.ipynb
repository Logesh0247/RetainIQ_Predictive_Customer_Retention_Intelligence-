# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

plt.style.use("default")
sns.set_theme()

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd

df = pd.read_csv(r"../Risk_segmentation/outputs/customer_risk_segments.csv")
df
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Churn Score  \
# 0                 2            53.85         108.15            1           86
# 1                 2            70.70         151.65            1           67
# 2                 8            99.65         820.50            1           86
# 3                28           104.80        3046.05            1           84
# 4                49           103.70        5036.30            1           89
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0           45
# 7039             24            84.80        1990.50            0           59
# 7040             72           103.20        7362.90            0           71
# 7041             11            29.60         346.45            0           59
# 7042             66           105.65        6844.50            0           38
#
#       CLTV  Revenue_Per_Month  Customer_Value  Service_Count  Gender_Male  \
# 0     3239          36.050000           107.7              3         True
# 1     2701          50.550000           141.4              1        False
# 2     5372          91.166667           797.2              5        False
# 3     5003         105.036207          2934.4              6        False
# 4     5340         100.726000          5081.3              6         True
# ...    ...                ...             ...            ...          ...
# 7038  5306          19.443836          1522.8              1        False
# 7039  2140          79.620000          2035.2              7         True
# 7040  5560         100.861644          7430.4              6        False
# 7041  2793          28.870833           325.6              1        False
# 7042  5097         102.156716          6972.9              6         True
#
#       ...  Streaming Movies_No internet service  Streaming Movies_Yes  \
# 0     ...                                 False                 False
# 1     ...                                 False                 False
# 2     ...                                 False                  True
# 3     ...                                 False                  True
# 4     ...                                 False                  True
# ...   ...                                   ...                   ...
# 7038  ...                                  True                 False
# 7039  ...                                 False                  True
# 7040  ...                                 False                  True
# 7041  ...                                 False                 False
# 7042  ...                                 False                  True
#
#       Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 0                 False              False                   True
# 1                 False              False                   True
# 2                 False              False                   True
# 3                 False              False                   True
# 4                 False              False                   True
# ...                 ...                ...                    ...
# 7038              False               True                   True
# 7039               True              False                   True
# 7040               True              False                   True
# 7041              False              False                   True
# 7042              False               True                   True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                      False                            False
# 1                                      False                             True
# 2                                      False                             True
# 3                                      False                             True
# 4                                      False                            False
# ...                                      ...                              ...
# 7038                                   False                            False
# 7039                                   False                            False
# 7040                                    True                            False
# 7041                                   False                             True
# 7042                                   False                            False
#
#       Payment Method_Mailed check  Churn_Probability  Risk_Segment
# 0                            True              0.945     High Risk
# 1                           False              0.840     High Risk
# 2                           False              0.950     High Risk
# 3                           False              0.880     High Risk
# 4                           False              0.895     High Risk
# ...                           ...                ...           ...
# 7038                        False              0.000      Low Risk
# 7039                         True              0.030      Low Risk
# 7040                        False              0.075      Low Risk
# 7041                        False              0.025      Low Risk
# 7042                        False              0.015      Low Risk
#
# [7043 rows x 38 columns]

# %% [markdown]
# ## Dataset Check

# %%
print(df.info())
print(df["Risk_Segment"].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Tenure Months                           7043 non-null   int64
#  1   Monthly Charges                         7043 non-null   float64
#  2   Total Charges                           7043 non-null   float64
#  3   Churn Value                             7043 non-null   int64
#  4   Churn Score                             7043 non-null   int64
#  5   CLTV                                    7043 non-null   int64
#  6   Revenue_Per_Month                       7043 non-null   float64
#  7   Customer_Value                          7043 non-null   float64
#  8   Service_Count                           7043 non-null   int64
#  9   Gender_Male                             7043 non-null   bool
#  10  Senior Citizen_Yes                      7043 non-null   bool
#  11  Partner_Yes                             7043 non-null   bool
#  12  Dependents_Yes                          7043 non-null   bool
#  13  Phone Service_Yes                       7043 non-null   bool
#  14  Multiple Lines_No phone service         7043 non-null   bool
#  15  Multiple Lines_Yes                      7043 non-null   bool
#  16  Internet Service_Fiber optic            7043 non-null   bool
#  17  Internet Service_No                     7043 non-null   bool
#  18  Online Security_No internet service     7043 non-null   bool
#  19  Online Security_Yes                     7043 non-null   bool
#  20  Online Backup_No internet service       7043 non-null   bool
#  21  Online Backup_Yes                       7043 non-null   bool
#  22  Device Protection_No internet service   7043 non-null   bool
#  23  Device Protection_Yes                   7043 non-null   bool
#  24  Tech Support_No internet service        7043 non-null   bool
#  25  Tech Support_Yes                        7043 non-null   bool
#  26  Streaming TV_No internet service        7043 non-null   bool
#  27  Streaming TV_Yes                        7043 non-null   bool
#  28  Streaming Movies_No internet service    7043 non-null   bool
#  29  Streaming Movies_Yes                    7043 non-null   bool
#  30  Contract_One year                       7043 non-null   bool
#  31  Contract_Two year                       7043 non-null   bool
#  32  Paperless Billing_Yes                   7043 non-null   bool
#  33  Payment Method_Credit card (automatic)  7043 non-null   bool
#  34  Payment Method_Electronic check         7043 non-null   bool
#  35  Payment Method_Mailed check             7043 non-null   bool
#  36  Churn_Probability                       7043 non-null   float64
#  37  Risk_Segment                            7043 non-null   object
# dtypes: bool(27), float64(5), int64(5), object(1)
# memory usage: 791.1+ KB
# None
# Risk_Segment
# Low Risk       5173
# High Risk      1528
# Medium Risk     342
# Name: count, dtype: int64

# %% [markdown]
# ## Create Retention Recommendation Function

# %%
import sys
from pathlib import Path
import pandas as pd

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils.recommendation import retention_action_label, generate_recommendation_summary

def retention_recommendation(row):
    """Same engine as the Flask app / bulk CSV export."""
    risk = row.get("Risk_Segment", "")
    prob = float(row.get("Churn_Probability", 0) or 0)
    return retention_action_label(row, prob, risk)

# %% [markdown]
# ## Generating Recommendation

# %%
df["Retention_Recommendation"] = df.apply(retention_recommendation,axis=1)

df[["Risk_Segment","Retention_Recommendation"]].head()
# Out:
#   Risk_Segment   Retention_Recommendation
# 0    High Risk  Welcome Retention Package
# 1    High Risk  Welcome Retention Package
# 2    High Risk         Offer 15% Discount
# 3    High Risk         Offer 15% Discount
# 4    High Risk         Offer 15% Discount

# %% [markdown]
# ## Potential Revenue Saved

# %%
df["Potential_Revenue_Saved"] = (df["Monthly Charges"] * 12)

# %% [markdown]
# ## View Results

# %%
df[["Risk_Segment","Monthly Charges","CLTV","Retention_Recommendation","Potential_Revenue_Saved"]].head()
# Out:
#   Risk_Segment  Monthly Charges  CLTV   Retention_Recommendation  \
# 0    High Risk            53.85  3239  Welcome Retention Package
# 1    High Risk            70.70  2701  Welcome Retention Package
# 2    High Risk            99.65  5372         Offer 15% Discount
# 3    High Risk           104.80  5003         Offer 15% Discount
# 4    High Risk           103.70  5340         Offer 15% Discount
#
#    Potential_Revenue_Saved
# 0                    646.2
# 1                    848.4
# 2                   1195.8
# 3                   1257.6
# 4                   1244.4

# %% [markdown]
# ## Save Main Recommendation File

# %%
df.to_csv("../retention_Intelligence/outputs/customer_retention_recommendations.csv",index=False)

print("Main Recommendation File Saved")
# Out:
# Main Recommendation File Saved

# %% [markdown]
# ## High Risk Customer Action List

# %%
high_risk = df[df["Risk_Segment"] == "High Risk"]

high_risk.to_csv("../retention_Intelligence/outputs/high_risk_retention_actions.csv",index=False)

print("High Risk File Saved")
# Out:
# High Risk File Saved

# %% [markdown]
# ## Retention Summary

# %%
summary = df.groupby("Retention_Recommendation").agg(
                        Customer_Count=("Risk_Segment","count"),
                        Avg_Churn_Probability=("Churn_Probability","mean"),
                        Avg_Monthly_Charges=("Monthly Charges","mean"),
                        Revenue_Saved=("Potential_Revenue_Saved","sum"))

summary = summary.reset_index()

summary
# Out:
#         Retention_Recommendation  Customer_Count  Avg_Churn_Probability  \
# 0              5% Discount Offer             140               0.699071
# 1           Free Online Security             135               0.900370
# 2           Free Premium Support              27               0.914630
# 3         Loyalty Reward Program              43               0.706628
# 4             Offer 15% Discount             770               0.930604
# 5        Personal Retention Call               5               0.891000
# 6     Promote Long-Term Contract               6               0.904167
# 7         Security Upgrade Offer             159               0.698522
# 8   Standard Customer Engagement            3143               0.046616
# 9          VIP Customer Benefits            2030               0.036424
# 10     Welcome Retention Package             585               0.929590
#
#     Avg_Monthly_Charges  Revenue_Saved
# 0             95.773571       160899.6
# 1             57.715556        93499.2
# 2             64.764815        20983.8
# 3             58.934884        30410.4
# 4             93.885844       867505.2
# 5             72.640000         4358.4
# 6             64.508333         4644.6
# 7             49.871384        95154.6
# 8             58.613777      2210677.2
# 9             65.111552      1586117.4
# 10            56.858803       399148.8

# %% [markdown]
# ## Save Summary

# %%
summary.to_csv("../retention_Intelligence/outputs/retention_summary.csv",index=False)

# %% [markdown]
# ## Strategy Distribution

# %%
strategy_distribution = (df["Retention_Recommendation"].value_counts().reset_index())

strategy_distribution.columns = ["Strategy","Customer_Count"]

strategy_distribution
# Out:
#                         Strategy  Customer_Count
# 0   Standard Customer Engagement            3143
# 1          VIP Customer Benefits            2030
# 2             Offer 15% Discount             770
# 3      Welcome Retention Package             585
# 4         Security Upgrade Offer             159
# 5              5% Discount Offer             140
# 6           Free Online Security             135
# 7         Loyalty Reward Program              43
# 8           Free Premium Support              27
# 9     Promote Long-Term Contract               6
# 10       Personal Retention Call               5

# %% [markdown]
# ## Save Distribution

# %%
strategy_distribution.to_csv("../retention_Intelligence/outputs/retention_strategy_distribution.csv",index=False)

# %% [markdown]
# ## Revenue Saved Summary

# %%
revenue_saved = (df.groupby("Retention_Recommendation")["Potential_Revenue_Saved"].sum().reset_index())

revenue_saved
# Out:
#         Retention_Recommendation  Potential_Revenue_Saved
# 0              5% Discount Offer                 160899.6
# 1           Free Online Security                  93499.2
# 2           Free Premium Support                  20983.8
# 3         Loyalty Reward Program                  30410.4
# 4             Offer 15% Discount                 867505.2
# 5        Personal Retention Call                   4358.4
# 6     Promote Long-Term Contract                   4644.6
# 7         Security Upgrade Offer                  95154.6
# 8   Standard Customer Engagement                2210677.2
# 9          VIP Customer Benefits                1586117.4
# 10     Welcome Retention Package                 399148.8

# %% [markdown]
# ## Save Revenue File

# %%
revenue_saved.to_csv("../retention_Intelligence/outputs/retention_revenue_saved.csv",index=False)

# %% [markdown]
# ## KPI Dashboard

# %%
print("="*50)

print("TOTAL CUSTOMERS")
print(len(df))

print("="*50)

print("HIGH RISK CUSTOMERS")
print((df["Risk_Segment"]=="High Risk").sum())

print("="*50)

print("TOTAL POTENTIAL REVENUE SAVED")
print(
    round(df["Potential_Revenue_Saved"].sum(),2))

print("="*50)

print("AVERAGE CHURN PROBABILITY")
print(round(df["Churn_Probability"].mean(),4))

print("="*50)

print("MOST COMMON STRATEGY")
print(df["Retention_Recommendation"].mode()[0])
# Out:
# ==================================================
# TOTAL CUSTOMERS
# 7043
# ==================================================
# HIGH RISK CUSTOMERS
# 1528
# ==================================================
# TOTAL POTENTIAL REVENUE SAVED
# 5473399.2
# ==================================================
# AVERAGE CHURN PROBABILITY
# 0.2664
# ==================================================
# MOST COMMON STRATEGY
# Standard Customer Engagement

# %% [markdown]
# ## Visualizations

# %%
## Retention Strategy Distribution

plt.figure(figsize=(12,6))

sns.countplot(data=df,y="Retention_Recommendation",order=df["Retention_Recommendation"].value_counts().index)

plt.title("Retention Strategy Distribution")

plt.tight_layout()

plt.savefig("../retention_Intelligence/visualizations/retention_strategy_distribution.png")

plt.show()

# %%
## Risk Segment vs Recommendation

plt.figure(figsize=(14,7))

sns.countplot(data=df,x="Risk_Segment",hue="Retention_Recommendation")

plt.title("Risk Segment vs Recommendation")

plt.tight_layout()

plt.savefig("../retention_Intelligence/visualizations/risk_vs_recommendation.png")

plt.show()

# %%
## Revenue Saved by Strategy
plt.figure(figsize=(12,6))

sns.barplot(data=revenue_saved,x="Retention_Recommendation",y="Potential_Revenue_Saved")

plt.xticks(rotation=45)

plt.title("Revenue Saved By Strategy")

plt.tight_layout()

plt.savefig("../retention_Intelligence/visualizations/revenue_saved_by_strategy.png")

plt.show()

# %%
## Risk Segment Distribution

plt.figure(figsize=(8,5))

sns.countplot(data=df,x="Risk_Segment")

plt.title("Risk Segment Distribution")

plt.tight_layout()

plt.savefig("../retention_Intelligence/visualizations/high_risk_customers.png")

plt.show()

# %%
## Churn Probability by Risk Segment
plt.figure(figsize=(8,5))

sns.boxplot(data=df,x="Risk_Segment",y="Churn_Probability")

plt.title("Churn Probability by Risk Segment")

plt.tight_layout()

plt.savefig("../retention_Intelligence/visualizations/churn_probability_by_segment.png")

plt.show()
